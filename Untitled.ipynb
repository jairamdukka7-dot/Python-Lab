# %%
def factorial(n):
    if n == 1:
        return 1
    else:
        return n * factorial(n - 1)
n = int(input("Enter a number: "))
if n < 0:
    print("Sorry, factorial does not exist for a negative number")
elif n==0:
    print("Factorial of 0 is 1")
else:
    print("Factorial of", n, "is", factorial(n))
# Out:
# Enter a number: 5
# Factorial of 5 is 120

# %%
class Shape:
    def __init__(self, name):
        self.name=name
    def area(self):
        raise NotImplementedError("Subclass must implement abstract method")
class Rectangle(Shape):
    def __init__(self,name,width,height):
        super().__init__(name)
        self.width=width
        self.height=height
    def area(self):
        return self.width*self.height
class Circle(Shape):
    def __init__(self,name,radius):
        super().__init__(name)
        self.radius=radius
    def area(self):
        return 3.14*self.radius*self.radius
class Triangle(Shape):
    def __init__(self,name,base,height):
        super().__init__(name)
        self.base=base
        self.height=height
    def area(self):
        return 0.5*self.base*self.height
def print_area(shape):
    print("Area of",shape.name,"is",shape.area(),"square units")
r=Rectangle("Rectangle",5,10)
c=Circle("Circle",7)
t=Triangle("Triangle",6,8)
print_area(r)
print_area(c)
print_area(t)
# Out:
# Area of Rectangle is 50 square units
# Area of Circle is 153.86 square units
# Area of Triangle is 24.0 square units

# %%
def add(x,y,z=0):
    return x+y+z
print("SUM=",add(2,3))
print("SUM=",add(2,3,4))
# Out:
# SUM= 5
# SUM= 9

# %%
try:
    n=int(input("Enter:"))
    r=10/n
    print(f"Result of division{r}")
except ZeroDivisionError:
    print("Can't Divide by Zero")
except ValueError:
    print("Error:Invalid input! Please enter a valid number.")
finally:
    print("End of the Program")
# Out:
# Enter:5
# Result of division2.0
# End of the Program

# %%
ss="Hello, Python Programming"
x=len(ss)
print("Length of String",x)
uc=ss.upper()
print("Uppercase String",uc)
lc=ss.lower()
print("Lowercase String",lc)
# Out:
# Length of String 25
# Uppercase String HELLO, PYTHON PROGRAMMING
# Lowercase String hello, python programming

# %%
ss="aditya college of computer science"
print("String in title case:",ss.title())
ans=ss.startswith("Hello")
print("Does the string starts with 'Hello':",ans)
ans1=ss.endswith("World!")
print("Does the string starts with 'World!':",ans1)
# Out:
# String in title case Aditya College Of Computer Science
# Does the string starts with 'Hello' False
# Does the string starts with 'World!' False

# %%
import pandas as pd
def import_CSV
